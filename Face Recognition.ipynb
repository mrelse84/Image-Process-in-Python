# %% [markdown]
# # Face Recognition

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## scikit-image

# %%
#!pip install scikit-image

import skimage
skimage.__version__
# Out:
# '0.16.2'

# %% [markdown]
# ## OpenCV

# %%
#!pip install opencv-contrib-python

# %%
import cv2
cv2.__version__
# Out:
# '4.2.0'

# %% [markdown]
# ## Wget

# %%
# !pip install wget
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 21.3 is available.
# You should consider upgrading via the 'c:\users\mrels\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import wget

# %%
wget.download('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml')
# Out:
# 100% [........................................................] 930127 / 930127
# 'haarcascade_frontalface_default.xml'

# %%
wget.download('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml')
# Out:
# 100% [........................................................] 341406 / 341406
# 'haarcascade_eye.xml'

# %%
from matplotlib.patches import Rectangle

# %%
def DetectFaceEye(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)

    face = faces[0]
    eye1 = eyes[0]
    eye2 = eyes[1]

    fig, ax = plt.subplots()
    fig.set_size_inches(18.5, 10.5, forward=True)

    plt.imshow(img, cmap=plt.cm.bone)
    plt.axis("off")
    plt.grid(False)
    ax.add_patch(Rectangle((face[0], face[1]), face[2], face[3], fill=False, color="r"))
    ax.add_patch(Rectangle((eye1[0], eye1[1]), eye1[2], eye1[3], fill=False))
    ax.add_patch(Rectangle((eye2[0], eye2[1]), eye2[2], eye2[3], fill=False))
    plt.show()

# %%
img = skimage.data.astronaut()
DetectFaceEye(img)

# %%
img2 = cv2.imread('lena.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_RGB2BGR)
DetectFaceEye(img2)
